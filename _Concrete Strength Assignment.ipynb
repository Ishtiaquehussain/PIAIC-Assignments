# %% [markdown]
# # Assignment: Compresive Strength Concrete Problem
#
#
# ### Abstract:
#
# Concrete is the most important material in civil engineering. The concrete compressive strength (concrete strength to bear the load) is a highly nonlinear function of age and ingredients.  <br><br>
#
# <table border="1"  cellpadding="6" bordercolor="red">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">1030</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">9</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">2007-08-03</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Regression</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">231464</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ###  Description:
# | Features Name | Data Type | Measurement | Description |
# | -- | -- | -- | -- |
# Cement (component 1) | quantitative | kg in a m3 mixture | Input Variable
# Blast Furnace Slag (component 2) | quantitative | kg in a m3 mixture | Input Variable
# Fly Ash (component 3) | quantitative | kg in a m3 mixture | Input Variable
# Water (component 4) | quantitative | kg in a m3 mixture | Input Variable
# Superplasticizer (component 5) | quantitative | kg in a m3 mixture | Input Variable
# Coarse Aggregate (component 6) | quantitative | kg in a m3 mixture | Input Variable
# Fine Aggregate (component 7) | quantitative | kg in a m3 mixture | Input Variable
# Age | quantitative | Day (1~365) | Input Variable
# Concrete compressive strength | quantitative | MPa | Output Variable
#
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature )
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
# - Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
# - Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# - Train the Model with Epochs (100) and validate it
# - If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/compresive_strength_concrete.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('//content/drive/MyDrive/AI_Assignment/AI_ASSIGNMENTS/compresive_strength_concrete.txt')

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
np.where(data.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
X_train = data.sample(frac = 0.7, random_state = 123)
X_test = data.drop(X_train.index)

# %%
X_train.head()
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 134                                      362.6  ...                                             71.30
# 13                                       190.0  ...                                             42.33
# 996                                      152.6  ...                                             26.86
# 770                                      349.0  ...                                             14.99
# 937                                      313.3  ...                                             36.80
#
# [5 rows x 9 columns]

# %% [markdown]
# # Assigning features and target variable

# %%
Y_train = X_train.iloc[:,-1]
X_train = X_train.iloc[:,0:-1]
Y_test = X_test.iloc[:,-1]
X_test = X_test.iloc[:,0:-1]

# %%
X_mean = X_train.mean()
X_train -= X_mean
X_std = X_train.std()
X_train /= X_std
X_test -= X_mean
X_test /= X_std

# %%
Y_mean = Y_train.mean()
Y_train -= Y_mean
Y_std = Y_train.std()
Y_train /= Y_std
Y_test -= Y_mean
Y_test /= Y_std

# %%
X_train.dtypes
# Out:
# Cement (component 1)(kg in a m^3 mixture)                float64
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    float64
# Fly Ash (component 3)(kg in a m^3 mixture)               float64
# Water  (component 4)(kg in a m^3 mixture)                float64
# Superplasticizer (component 5)(kg in a m^3 mixture)      float64
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     float64
# Fine Aggregate (component 7)(kg in a m^3 mixture)        float64
# Age (day)                                                float64
# dtype: object

# %%
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()
X_test = X_test.to_numpy()
Y_test = Y_test.to_numpy()

# %% [markdown]
# # Training and testing data splittion

# %% [markdown]
# # Model selection

# %%
from tensorflow.keras import layers as L
from tensorflow.keras import models as M

# %%
network = M.Sequential()

# %%
network.add(L.Dense(128,activation="relu",input_shape=(X_train.shape[1],)))

# %%
network.add(L.Dense(64,activation="relu"))

# %%
network.add(L.Dense(32,activation="relu"))

# %%
network.add(L.Dense(1))

# %%
network.compile(optimizer="rmsprop",loss=["mse"],metrics=["mae"])

# %%
history = network.fit(X_train,Y_train,epochs=200,validation_split=0.3, batch_size = 16)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 1s 7ms/step - loss: 0.7396 - mae: 0.6814 - val_loss: 0.3953 - val_mae: 0.5001
# Epoch 2/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3189 - mae: 0.4523 - val_loss: 0.3230 - val_mae: 0.4180
# Epoch 3/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2263 - mae: 0.3656 - val_loss: 0.2576 - val_mae: 0.3772
# Epoch 4/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1938 - mae: 0.3374 - val_loss: 0.2397 - val_mae: 0.3716
# Epoch 5/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1476 - mae: 0.2886 - val_loss: 0.2186 - val_mae: 0.3567
# Epoch 6/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1372 - mae: 0.2842 - val_loss: 0.2069 - val_mae: 0.3416
# Epoch 7/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1173 - mae: 0.2724 - val_loss: 0.1889 - val_mae: 0.3174
# Epoch 8/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1019 - mae: 0.2458 - val_loss: 0.1836 - val_mae: 0.3119
# Epoch 9/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0950 - mae: 0.2391 - val_loss: 0.2101 - val_mae: 0.3375
# Epoch 10/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0961 - mae: 0.2354 - val_loss: 0.1809 - val_mae: 0.3173
# Epoch 11/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0853 - mae: 0.2248 - val_loss: 0.1628 - val_mae: 0.2957
# Epoch 12/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0880 - mae: 0.2258 - val_loss: 0.1678 - val_mae: 0.3137
# Epoch 13/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0797 - mae: 0.2178 - val_loss: 0.1781 - val_mae: 0.3214
# Epoch 14/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0834 - mae: 0.2242 - val_loss: 0.1688 - val_mae: 0.3100
# Epoch 15/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0619 - mae: 0.1938 - val_loss: 0.1605 - val_mae: 0.2954
# Epoch 16/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0660 - mae: 0.1961 - val_loss: 0.1798 - val_mae: 0.3148
# Epoch 17/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0644 - mae: 0.1950 - val_loss: 0.1797 - val_mae: 0.3173
# Epoch 18/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0538 - mae: 0.1788 - val_loss: 0.1493 - val_mae: 0.2986
# Epoch 19/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0637 - mae: 0.1949 - val_loss: 0.1472 - val_mae: 0.2799
# Epoch 20/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0692 - mae: 0.2036 - val_loss: 0.1386 - val_mae: 0.2775
# Epoch 21/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0630 - mae: 0.1890 - val_loss: 0.1355 - val_mae: 0.2763
# Epoch 22/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0546 - mae: 0.1776 - val_loss: 0.1421 - val_mae: 0.2931
# Epoch 23/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0471 - mae: 0.1644 - val_loss: 0.1299 - val_mae: 0.2709
# Epoch 24/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0449 - mae: 0.1673 - val_loss: 0.1323 - val_mae: 0.2705
# Epoch 25/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0491 - mae: 0.1672 - val_loss: 0.1691 - val_mae: 0.3144
# Epoch 26/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0577 - mae: 0.1867 - val_loss: 0.1479 - val_mae: 0.2904
# Epoch 27/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0435 - mae: 0.1621 - val_loss: 0.2051 - val_mae: 0.3370
# Epoch 28/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0479 - mae: 0.1625 - val_loss: 0.1407 - val_mae: 0.2824
# Epoch 29/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0359 - mae: 0.1399 - val_loss: 0.1448 - val_mae: 0.2978
# Epoch 30/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0572 - mae: 0.1837 - val_loss: 0.1251 - val_mae: 0.2693
# Epoch 31/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0475 - mae: 0.1674 - val_loss: 0.1500 - val_mae: 0.2973
# Epoch 32/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0479 - mae: 0.1646 - val_loss: 0.1258 - val_mae: 0.2667
# Epoch 33/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0474 - mae: 0.1584 - val_loss: 0.1257 - val_mae: 0.2630
# Epoch 34/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0481 - mae: 0.1582 - val_loss: 0.1193 - val_mae: 0.2586
# Epoch 35/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0402 - mae: 0.1486 - val_loss: 0.1289 - val_mae: 0.2672
# Epoch 36/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0419 - mae: 0.1545 - val_loss: 0.1322 - val_mae: 0.2764
# Epoch 37/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0368 - mae: 0.1433 - val_loss: 0.1347 - val_mae: 0.2666
# Epoch 38/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0459 - mae: 0.1509 - val_loss: 0.1326 - val_mae: 0.2706
# Epoch 39/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0530 - mae: 0.1581 - val_loss: 0.1223 - val_mae: 0.2549
# Epoch 40/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.
200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0286 - mae: 0.1200 - val_loss: 0.1136 - val_mae: 0.2407
# Epoch 76/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0329 - mae: 0.1217 - val_loss: 0.1196 - val_mae: 0.2645
# Epoch 77/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0237 - mae: 0.1117 - val_loss: 0.1396 - val_mae: 0.2677
# Epoch 78/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0368 - mae: 0.1334 - val_loss: 0.1334 - val_mae: 0.2654
# Epoch 79/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0304 - mae: 0.1197 - val_loss: 0.1145 - val_mae: 0.2453
# Epoch 80/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0384 - mae: 0.1440 - val_loss: 0.1230 - val_mae: 0.2585
# Epoch 81/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0269 - mae: 0.1169 - val_loss: 0.1103 - val_mae: 0.2378
# Epoch 82/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0267 - mae: 0.1183 - val_loss: 0.1145 - val_mae: 0.2413
# Epoch 83/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0270 - mae: 0.1107 - val_loss: 0.1121 - val_mae: 0.2477
# Epoch 84/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0225 - mae: 0.1020 - val_loss: 0.1333 - val_mae: 0.2664
# Epoch 85/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0246 - mae: 0.1157 - val_loss: 0.1182 - val_mae: 0.2502
# Epoch 86/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0250 - mae: 0.1145 - val_loss: 0.1232 - val_mae: 0.2473
# Epoch 87/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0361 - mae: 0.1296 - val_loss: 0.1590 - val_mae: 0.2974
# Epoch 88/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0274 - mae: 0.1203 - val_loss: 0.1150 - val_mae: 0.2527
# Epoch 89/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0262 - mae: 0.1168 - val_loss: 0.1166 - val_mae: 0.2528
# Epoch 90/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.1034 - val_loss: 0.1134 - val_mae: 0.2443
# Epoch 91/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0279 - mae: 0.1154 - val_loss: 0.1259 - val_mae: 0.2574
# Epoch 92/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.1039 - val_loss: 0.1263 - val_mae: 0.2523
# Epoch 93/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0276 - mae: 0.1158 - val_loss: 0.1080 - val_mae: 0.2426
# Epoch 94/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0244 - mae: 0.1066 - val_loss: 0.1084 - val_mae: 0.2383
# Epoch 95/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0200 - mae: 0.1046 - val_loss: 0.1146 - val_mae: 0.2522
# Epoch 96/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0259 - mae: 0.1102 - val_loss: 0.1117 - val_mae: 0.2407
# Epoch 97/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0211 - mae: 0.1015 - val_loss: 0.1150 - val_mae: 0.2431
# Epoch 98/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0311 - mae: 0.1262 - val_loss: 0.1049 - val_mae: 0.2391
# Epoch 99/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0236 - mae: 0.1054 - val_loss: 0.1086 - val_mae: 0.2315
# Epoch 100/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0204 - mae: 0.0983 - val_loss: 0.1092 - val_mae: 0.2477
# Epoch 101/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0250 - mae: 0.1117 - val_loss: 0.1116 - val_mae: 0.2330
# Epoch 102/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0199 - mae: 0.0956 - val_loss: 0.1097 - val_mae: 0.2406
# Epoch 103/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0241 - mae: 0.1023 - val_loss: 0.1152 - val_mae: 0.2547
# Epoch 104/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0246 - mae: 0.1066 - val_loss: 0.1163 - val_mae: 0.2422
# Epoch 105/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0235 - mae: 0.1069 - val_loss: 0.1235 - val_mae: 0.2548
# Epoch 106/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0222 - mae: 0.1069 - val_loss: 0.1132 - val_mae: 0.2391
# Epoch 107/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0204 - mae: 0.0983 - val_loss: 0.1111 - val_mae: 0.2437
# Epoch 108/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0313 - mae: 0.1201 - val_loss: 0.1151 - val_mae: 0.2440
# Epoch 109/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0208 - mae: 0.1051 - val_loss: 0.1016 - val_mae: 0.2319
# Epoch 110/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.
200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0208 - mae: 0.0928 - val_loss: 0.1018 - val_mae: 0.2257
# Epoch 181/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0147 - mae: 0.0810 - val_loss: 0.1020 - val_mae: 0.2272
# Epoch 182/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.0937 - val_loss: 0.1077 - val_mae: 0.2444
# Epoch 183/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0180 - mae: 0.0854 - val_loss: 0.0991 - val_mae: 0.2215
# Epoch 184/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0158 - mae: 0.0789 - val_loss: 0.1026 - val_mae: 0.2284
# Epoch 185/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0164 - mae: 0.0799 - val_loss: 0.1109 - val_mae: 0.2509
# Epoch 186/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0194 - mae: 0.0904 - val_loss: 0.1100 - val_mae: 0.2387
# Epoch 187/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0211 - mae: 0.0965 - val_loss: 0.1202 - val_mae: 0.2468
# Epoch 188/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0166 - mae: 0.0856 - val_loss: 0.1047 - val_mae: 0.2284
# Epoch 189/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0174 - mae: 0.0898 - val_loss: 0.1076 - val_mae: 0.2331
# Epoch 190/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0157 - mae: 0.0801 - val_loss: 0.1072 - val_mae: 0.2278
# Epoch 191/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0134 - mae: 0.0771 - val_loss: 0.1059 - val_mae: 0.2355
# Epoch 192/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0134 - mae: 0.0800 - val_loss: 0.1100 - val_mae: 0.2366
# Epoch 193/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0158 - mae: 0.0863 - val_loss: 0.1112 - val_mae: 0.2318
# Epoch 194/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0132 - mae: 0.0792 - val_loss: 0.1062 - val_mae: 0.2313
# Epoch 195/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0194 - mae: 0.0931 - val_loss: 0.1037 - val_mae: 0.2246
# Epoch 196/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0139 - mae: 0.0743 - val_loss: 0.1170 - val_mae: 0.2393
# Epoch 197/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0135 - mae: 0.0773 - val_loss: 0.1121 - val_mae: 0.2394
# Epoch 198/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0148 - mae: 0.0801 - val_loss: 0.1066 - val_mae: 0.2345
# Epoch 199/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0138 - mae: 0.0770 - val_loss: 0.1137 - val_mae: 0.2451
# Epoch 200/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0141 - mae: 0.0816 - val_loss: 0.1041 - val_mae: 0.2310

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
loss,mae=network.evaluate(X_test,Y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1312 - mae: 0.2353

# %%
val_mae = history.history['val_mae']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt 
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(200)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
acc_values = history_dict['mae']
val_acc_values = history_dict['val_mae']
plt.plot(epochs, acc_values, 'bo', label='Training mae')
plt.plot(epochs, val_acc_values, 'b', label='Validation mae')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
y_pred = network.predict(X_test)

# %%
def denorm(x):
    return (x * Y_std) + Y_mean

# %%
y_pred = denorm(y_pred)

# %%
y_true = denorm(Y_test)

# %%
y_pred = y_pred.flatten()

# %%
y_pred.shape
# Out:
# (309,)

# %%
y_true.shape
# Out:
# (309,)

# %%
import numpy as np
import matplotlib.pyplot as plt
coef = np.polyfit(y_true,y_pred,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y
plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
plt.xlim(0, 100)
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)
